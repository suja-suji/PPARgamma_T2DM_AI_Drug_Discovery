# %% [markdown]
# Rosiglitazone scaffold

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (36.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 67.0 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.1

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Scaffolds import MurckoScaffold # Import the MurckoScaffold submodule

# Rosiglitazone SMILES
rosiglitazone_smiles = "CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1"

# Create an RDKit molecule object
mol = Chem.MolFromSmiles(rosiglitazone_smiles)

# Generate the Murcko scaffold
scaffold = MurckoScaffold.GetScaffoldForMol(mol) # Use the correct function name

# Display the scaffold image with increased size
Draw.MolToImage(scaffold, size=(400, 400)) # Increased size
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x400>

# %% [markdown]
# Finding Derivatives

# %% [markdown]
# Uploading file and extract necessary column

# %%
import pandas as pd
df = pd.read_csv("/content/PubChem rosi 77999.tsv" , sep='\t')
df.head()
# Out:
#    Compound_CID                                            Name  \
# 0         77999                                   Rosiglitazone
# 1       5281055                           Rosiglitazone Maleate
# 2       6445783  Metformin Hydrochloride; Rosiglitazone Maleate
# 3      10021239                               (+)-Rosiglitazone
# 4      10119132                  Didehydro rosiglitazone, (5Z)-
#
#                                             Synonyms  Molecular_Weight  \
# 0  rosiglitazone|122320-73-4|Rosiglizole|Brl-4965...             357.4
# 1  Rosiglitazone maleate|155141-29-0|BRL-49653C|R...             473.5
# 2  Rosiglitazone maleate and metformin hydrochlor...             639.1
# 3  (+)-rosiglitazone|(R)-Rosiglitazone|163860-16-...             357.4
# 4  Didehydro rosiglitazone, (5Z)-|7JSD8Q9B3G|2,4-...             355.4
#
#   Molecular_Formula  Polar_Area  Complexity  XLogP  Heavy_Atom_Count  \
# 0       C18H19N3O3S        96.8         468    3.1                25
# 1       C22H23N3O7S       171.0         587    NaN                33
# 2     C26H35ClN8O7S       263.0         719    NaN                43
# 3       C18H19N3O3S        96.8         468    3.1                25
# 4       C18H17N3O3S        96.8         518    3.2                25
#
#    H-Bond_Donor_Count  ...  Linked_PubChem_Patent_Count  \
# 0                   1  ...                        88332
# 1                   3  ...                        11098
# 2                   7  ...                          470
# 3                   1  ...                           34
# 4                   1  ...                           80
#
#    Linked_PubChem_Patent_Family_Count  MeSH_Headings  \
# 0                               17843  Rosiglitazone
# 1                                3007  Rosiglitazone
# 2                                  60            NaN
# 3                                  18            NaN
# 4                                  32            NaN
#
#                                   Annotation_Content Annotation_Type_Count  \
# 0  Biological Test Results|Interactions and Pathw...                    18
# 1  Biological Test Results|Interactions and Pathw...                    14
# 2  Interactions and Pathways|Chemical and Physica...                     8
# 3  Biological Test Results|Interactions and Pathw...                     8
# 4  Biological Test Results|Classification|Literat...                     7
#
#                                     Linked_BioAssays  Create_Date  \
# 0  388|507|875|880|881|884|885|887|889|892|893|89...     20050326
# 1  1195|1376|1385|1422|1465|1511|1529|1530|1531|1...     20050326
# 2                                                NaN     20060429
# 3                                      156380|156381     20061025
# 4  15885|115625|123660|123662|136639|136640|15623...     20061025
#
#                                          Data_Source  \
# 0  001Chemical|10X CHEM|1st Scientific|3WAY PHARM...
# 1  10X CHEM|1st Scientific|3WAY PHARM INC|A2B Che...
# 2  ABI Chem|BenchChem|ChemSpider|LeadScope|NextBi...
# 3  A&J Pharmtech CO., LTD.|Adooq BioScience|Ambin...
# 4  001Chemical|10X CHEM|AKos Consulting & Solutio...
#
#                                 Data_Source_Category  \
# 0  Chemical Vendors|Curation Efforts|Governmental...
# 1  Chemical Vendors|Curation Efforts|Governmental...
# 2  Chemical Vendors|Governmental Organizations|Jo...
# 3  Chemical Vendors|Curation Efforts|Governmental...
# 4  Chemical Vendors|Curation Efforts|Governmental...
#
#                                    Tagged_by_PubChem
# 0  A - Alimentary tract and metabolism > A10 - Dr...
# 1  C274 - Antineoplastic Agent > C2122 - Cell Dif...
# 2  D007004 - Hypoglycemic Agents > D001645 - Bigu...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 38 columns]

# %%
# Select the required columns
rosi_cid_smiles_df = df[['Compound_CID', 'SMILES']]

# Save the selected columns to a new TSV file
rosi_cid_smiles_df.to_csv('rosi cid and smiles.tsv', sep='\t', index=False)

print("Successfully extracted 'Compound_CID', and 'SMILES' and saved to 'rosi cid and smiles.tsv'")
# Out:
# Successfully extracted 'Compound_CID', and 'SMILES' and saved to 'rosi cid and smiles.tsv'

# %%
df=pd.read_csv("/content/rosi cid and smiles.tsv" , sep="\t")
df
# Out:
#      Compound_CID                                             SMILES
# 0           77999    CN(CCOC1=CC=C(C=C1)CC2C(=O)NC(=O)S2)C3=CC=CC=N3
# 1         5281055  CN(CCOC1=CC=C(C=C1)CC2C(=O)NC(=O)S2)C3=CC=CC=N...
# 2         6445783  CN(C)C(=N)N=C(N)N.CN(CCOC1=CC=C(C=C1)CC2C(=O)N...
# 3        10021239  CN(CCOC1=CC=C(C=C1)C[C@@H]2C(=O)NC(=O)S2)C3=CC...
# 4        10119132  CN(CCOC1=CC=C(C=C1)/C=C\2/C(=O)NC(=O)S2)C3=CC=...
# ..            ...                                                ...
# 564     176525113  [HH].CC(=N)N=C(CNC)N.CN(CCOC1=CC=C(C=C1)CC2C(=...
# 565     176535387  CN(C)C(=NC(=N)N)N.CN(CCOC1=CC=C(C=C1)CC2C(=O)N...
# 566     176537998  CN(C)C(=NC(=N)N)N.CN(CCOC1=CC=C(C=C1)CC2C(=O)N...
# 567     176542626  CCC1=CN=C(C=C1)CCOC2=CC=C(C=C2)CC3C(=O)NC(=O)S...
# 568     176546364  CN(C)/C(=N/C(=N)N)/N.CN(CCOC1=CC=C(C=C1)CC2C(=...
#
# [569 rows x 2 columns]

# %% [markdown]
# Converting Smile to Canonical smile

# %%
from rdkit import Chem
import pandas as pd

def to_canonical_smiles(smiles):
    """Converts a SMILES string to its canonical form using RDKit."""
    if pd.isna(smiles):
        return None
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        return Chem.MolToSmiles(mol, canonical=True)
    return None

# Load the dataframe
rosi_cid_smiles_df = pd.read_csv("/content/rosi cid and smiles.tsv" , sep="\t")

# Apply the function to the 'SMILES' column to convert to canonical SMILES
rosi_cid_smiles_df['SMILES'] = rosi_cid_smiles_df['SMILES'].apply(to_canonical_smiles)

# Save the updated DataFrame back to the original TSV file, keeping the header and using tab separation
rosi_cid_smiles_df.to_csv('/content/rosi cid and smiles.tsv', sep='\t', index=False, header=True)

print("Successfully converted SMILES to canonical form and saved to '/content/rosi cid and smiles.tsv'")
# Out:
# Successfully converted SMILES to canonical form and saved to '/content/rosi cid and smiles.tsv'
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors
# [08:13:41] WARNING: not removing hydrogen atom without neighbors

# %%
display(rosi_cid_smiles_df)
# Out:
#      Compound_CID                                             SMILES
# 0           77999            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1         5281055  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
# 2         6445783  CN(C)C(=N)N=C(N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 3        10021239        CN(CCOc1ccc(C[C@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 4        10119132         CN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1ccccn1
# ..            ...                                                ...
# 564     176525113  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.CNCC(N...
# 565     176535387  CN(C)C(N)=NC(=N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 566     176537998  CN(C)C(N)=NC(=N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 567     176542626  CCc1ccc(CCOc2ccc(CC3SC(=O)NC3=O)cc2)nc1.CN(C)C...
# 568     176546364  CN(C)/C(N)=N/C(=N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O...
#
# [569 rows x 2 columns]

# %% [markdown]
# Murcko Scaffold to find derivatives

# %%
import pandas as pd

# Load the data from the TSV file into a pandas DataFrame
rosi_df = pd.read_csv("/content/rosi cid and smiles.tsv", sep="\t")

# Display the first few rows of the DataFrame to confirm successful loading
display(rosi_df.head())
# Out:
#    Compound_CID                                             SMILES
# 0         77999            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1       5281055  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
# 2       6445783  CN(C)C(=N)N=C(N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 3      10021239        CN(CCOc1ccc(C[C@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 4      10119132         CN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1ccccn1

# %%
from rdkit import Chem
from rdkit.Chem.Scaffolds import MurckoScaffold

# Rosiglitazone SMILES (assuming you have this defined)
rosiglitazone_smiles = "CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1"

# Create RDKit molecule object for Rosiglitazone
rosiglitazone_mol = Chem.MolFromSmiles(rosiglitazone_smiles)

# Generate Murcko scaffold for Rosiglitazone
rosiglitazone_scaffold = MurckoScaffold.GetScaffoldForMol(rosiglitazone_mol)
rosiglitazone_scaffold_smiles = Chem.MolToSmiles(rosiglitazone_scaffold, canonical=True)

print(f"Rosiglitazone Scaffold SMILES: {rosiglitazone_scaffold_smiles}")

# Now, let's apply this to the DataFrame to find molecules with the same scaffold
def get_murcko_scaffold_smiles(smiles):
    """Generates canonical Murcko scaffold SMILES for a given SMILES string."""
    if pd.isna(smiles):
        return None
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        scaffold = MurckoScaffold.GetScaffoldForMol(mol)
        if scaffold is not None:
            return Chem.MolToSmiles(scaffold, canonical=True)
    return None

# Apply the function to the 'SMILES' column to get the scaffold SMILES for each molecule
rosi_df['Scaffold_SMILES'] = rosi_df['SMILES'].apply(get_murcko_scaffold_smiles)

# Identify derivatives by comparing their scaffold SMILES to the Rosiglitazone scaffold SMILES
derivatives_df = rosi_df[rosi_df['Scaffold_SMILES'] == rosiglitazone_scaffold_smiles]

# Display the derivatives
display(derivatives_df.head())

# Count the number of derivatives
num_derivatives = len(derivatives_df)
print(f"\nNumber of derivatives found: {num_derivatives}")

# Save the derivatives to a new TSV file, excluding the 'Scaffold_SMILES' column
derivatives_df.drop(columns=['Scaffold_SMILES']).to_csv('rosi cid derivatives.tsv', sep='\t', index=False)

print("\nSuccessfully saved 'rosi cid derivatives.tsv'")
# Out:
# Rosiglitazone Scaffold SMILES: O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:38] WARNING: not removing hydrogen atom without neighbors
# [08:20:39] WARNING: not removing hydrogen atom without neighbors
#    Compound_CID                                             SMILES  \
# 0         77999            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1       5281055  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
# 2       6445783  CN(C)C(=N)N=C(N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 5      25058199  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C([O...
# 6      12000328             O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
#
#                           Scaffold_SMILES
# 0  O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# 1  O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# 2  O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# 5  O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# 6  O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# Number of derivatives found: 194
#
# Successfully saved 'rosi cid derivatives.tsv'

# %%
df=pd.read_csv("/content/rosi cid derivatives.tsv" , sep="\t")
df
# Out:
#      Compound_CID                                             SMILES
# 0           77999            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1         5281055  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
# 2         6445783  CN(C)C(=N)N=C(N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 3        25058199  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C([O...
# 4        12000328             O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
# ..            ...                                                ...
# 189     168006914  O=C(O)/C=C/C(=O)O.[2H]C([2H])(CN(c1ccccn1)C([2...
# 190     176525113  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.CNCC(N...
# 191     176535387  CN(C)C(N)=NC(=N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 192     176537998  CN(C)C(N)=NC(=N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 193     176546364  CN(C)/C(N)=N/C(=N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O...
#
# [194 rows x 2 columns]

# %% [markdown]
# Tanimoto Similarity

# %%
# calculating tanimoto similarity for 194 compounds
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator, DataStructs
# Step 1:
# Load dataset - has chembl id, smiles, EC50
compounds_df = pd.read_csv("/content/rosi cid derivatives.tsv", sep="\t")

# Load datset - pio and rosi as reference compound for calculating tanimoto
ref_df = pd.read_csv("/content/rosi and pio smiles.tsv", sep="\t")


# Step 2: Setup Morgan generator
morgan_gen = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

def smiles_to_fp(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return morgan_gen.GetFingerprint(mol)
    else:
        return None

# Step 3: Get reference compounds
rosi_smiles = ref_df.loc[ref_df["Generic name"].str.contains("Rosi", case=False), "Smiles"].values[0]
pio_smiles  = ref_df.loc[ref_df["Generic name"].str.contains("Pio", case=False), "Smiles"].values[0]

rosi_fp = smiles_to_fp(rosi_smiles)
pio_fp  = smiles_to_fp(pio_smiles)

# Step 4: Compute tanimoto similarities
rosi_sims = []
pio_sims = []

for smi in compounds_df["SMILES"]:
    fp = smiles_to_fp(smi)
    if fp:
        rosi_sims.append(round(DataStructs.TanimotoSimilarity(rosi_fp, fp),4))
        pio_sims.append(round(DataStructs.TanimotoSimilarity(pio_fp, fp),4))
    else:
        rosi_sims.append(None)
        pio_sims.append(None)

compounds_df["Tanimoto_with_Rosi"] = rosi_sims
compounds_df["Tanimoto_with_Pio"]  = pio_sims


# Step 5: doing Average similarity to filter compounds

compounds_df["Average_Similarity"] = (
    compounds_df["Tanimoto_with_Rosi"] + compounds_df["Tanimoto_with_Pio"]
) / 2
compounds_df["Average_Similarity"] = compounds_df["Average_Similarity"].round(4)


# Step 6: Save results

output_file = "/content/rosi cid derivatives.tsv"
compounds_df.to_csv(output_file, sep="\t", index=False)

print("✅ Done! Results saved to:", output_file)
compounds_df.head()
# Out:
# ✅ Done! Results saved to: /content/rosi cid derivatives.tsv
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
# [08:21:37] WARNING: not removing hydrogen atom without neighbors
#    Compound_CID                                             SMILES  \
# 0         77999            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1       5281055  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
# 2       6445783  CN(C)C(=N)N=C(N)N.CN(CCOc1ccc(CC2SC(=O)NC2=O)c...
# 3      25058199  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C([O...
# 4      12000328             O=C1NC(=O)C(Cc2ccc(OCCNc3ccccn3)cc2)S1
#
#    Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity
# 0              1.0000             0.5246              0.7623
# 1              0.8727             0.4706              0.6717
# 2              0.6957             0.3902              0.5430
# 3              0.8421             0.4571              0.6496
# 4              0.6207             0.5167              0.5687

# %%
# fixing Threshold value of rosi and pio tanimoto sim score
threshold = 0.5245

# Count how many compounds pass
count_above = (compounds_df['Average_Similarity']>= threshold).sum()


# Total compounds
total_compounds = len(compounds_df)

# Print results
print(f"Compounds with Average_Similarity >= {threshold}: {count_above}")
# Out:
# Compounds with Average_Similarity >= 0.5245: 148

# %%
# save filtered compounds
filtered_df = compounds_df[compounds_df["Average_Similarity"] >= threshold]
filtered_df.to_csv("/content/rosi derivatives threshold.tsv", sep="\t", index=False)

print("Filtered compounds saved to: /content/rosi derivatives threshold.tsv")
# Out:
# Filtered compounds saved to: /content/rosi derivatives threshold.tsv
