# %%
# pandas already installed so just importing
import pandas as pd

# %%
# for reading files we need pandas
df=pd.read_csv('/content/5k data.tsv', sep='\t')

# %%
#to see the first few rows, if want mention the rows count inside the bracket
df.head()
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0       CHEMBL360368           NaN                 NaN            436.50
# 1       CHEMBL178321           NaN                 NaN            433.89
# 2       CHEMBL104246           NaN                 NaN            436.51
# 3        CHEMBL66206           NaN                 NaN            381.43
# 4       CHEMBL194698           NaN                 NaN            332.44
#
#    #RO5 Violations  AlogP Compound Key  \
# 0              1.0   5.36           1d
# 1              1.0   5.59            8
# 2              0.0   3.60           4c
# 3              0.0   4.51            6
# 4              0.0   4.03          14a
#
#                                               Smiles Standard Type  \
# 0  CCO[C@@H](Cc1ccc(OCCCOc2ccc(Oc3ccccc3)cc2)cc1)...          EC50
# 1  COc1ccc2c(c1)c(Cc1ccc(C(=O)O)cc1)c(C)n2C(=O)c1...          EC50
# 2  Cc1oc(-c2ccccc2)nc1CCOc1ccc(C[C@@H](C(=O)O)N2C...          EC50
# ...

# %%
#to get all the columns info and to see the missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5305 entries, 0 to 5304
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          5305 non-null   object
#  1   Molecule Name               516 non-null    object
#  2   Molecule Max Phase          445 non-null    float64
#  3   Molecular Weight            5305 non-null   float64
#  4   #RO5 Violations             5294 non-null   float64
#  5   AlogP                       5294 non-null   float64
#  6   Compound Key                5305 non-null   object
#  7   Smiles                      5305 non-null   object
#  8   Standard Type               5305 non-null   object
#  9   Standard Relation           4907 non-null   object
#  10  Standard Value              4933 non-null   float64
#  11  Standard Units              4987 non-null   object
#  12  pChEMBL Value               4031 non-null   float64
# ...

# %%
# Check if all 'Standard Type' values are 'EC50'
all_ec50 = (df['Standard Type'] == 'EC50').all()
print(f"Are all 'Standard Type' values 'EC50'? {all_ec50}")

# Check if all 'Standard Units' values are 'nM'
all_nm = (df['Standard Units'] == 'nM').all()
print(f"Are all 'Standard Units' values 'nM'? {all_nm}")

# Check for missing values in 'Standard Value'
missing_values_count = df['Standard Value'].isnull().sum()
print(f"Number of missing 'Standard Value' entries: {missing_values_count}")

# Check for negative or nonsensical values in 'Standard Value' (assuming positive values are expected for EC50)
# We'll consider non-positive values as potentially nonsensical
nonsensical_values_count = df[df['Standard Value'] <= 0]['Standard Value'].count()
print(f"Number of non-positive 'Standard Value' entries: {nonsensical_values_count}")

# Display some of the rows with missing or nonsensical values if any exist
if missing_values_count > 0:
    print("\nRows with missing 'Standard Value':")
    display(df[df['Standard Value'].isnull()].head())

if nonsensical_values_count > 0:
    print("\nRows with non-positive 'Standard Value':")
    display(df[df['Standard Value'] <= 0].head())
# Out:
# Are all 'Standard Type' values 'EC50'? True
# Are all 'Standard Units' values 'nM'? False
# Number of missing 'Standard Value' entries: 372
# Number of non-positive 'Standard Value' entries: 0
#
# Rows with missing 'Standard Value':
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 1         CHEMBL178321           NaN                 NaN            433.89
# 15        CHEMBL192291           NaN                 NaN            460.83
# 21        CHEMBL206202           NaN                 NaN            458.90
# 22        CHEMBL424674           NaN                 NaN            444.88
# 137      CHEMBL4576159           NaN                 NaN            429.48
#
#      #RO5 Violations  AlogP Compound Key  \
# 1                1.0   5.59            8
# 15               1.0   5.25           28
# 21               1.0   6.34           31
# 22               1.0   6.25           30
# 137              1.0   5.31       (R)-10
#
# ...

# %%
# Filter for rows where 'Standard Units' is not 'nM' and not missing
other_units_df = df[(df['Standard Units'] != 'nM') & (df['Standard Units'].notna())]

print("Rows with Standard Units other than 'nM':")
display(other_units_df)
# Out:
# Rows with Standard Units other than 'nM':
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 452       CHEMBL1956878           NaN                 NaN            292.42
# 1702       CHEMBL364774           NaN                 NaN            387.40
# 3128       CHEMBL192152           NaN                 NaN            373.37
# 3130       CHEMBL190645           NaN                 NaN            359.34
#
#       #RO5 Violations  AlogP Compound Key  \
# 452               0.0   4.08            2
# 1702              1.0   5.38            8
# 3128              0.0   4.99            4
# 3130              0.0   4.60            7
#
#                                               Smiles Standard Type  \
# 452                CCC/C=C\C#C/C=C/C(O)CCCCCCCC(=O)O          EC50
# 1702  CCCc1cc2c(C(F)(F)F)noc2c(CCC)c1OC(C)(CC)C(=O)O          EC50
# 3128   CCCc1cc2c(C(F)(F)F)noc2c(CCC)c1OC(C)(C)C(=O)O          EC50
# ...

# %%
# Get the value counts for the 'Standard Relation' column
relation_counts = df['Standard Relation'].value_counts(dropna=False)

print("Counts of symbols in 'Standard Relation' column:")
print(relation_counts)
# Out:
# Counts of symbols in 'Standard Relation' column:
# Standard Relation
# '='     4124
# '>'      748
# NaN      398
# '<'       21
# '~'        9
# '>='       5
# Name: count, dtype: int64

# %%
# selecting the columns

# Load file
df = pd.read_csv("/content/5k data.tsv", sep="\t")

# Rename 'Standard Value' → 'EC50'
df = df.rename(columns={"Standard Value": "EC50"})

# Select needed columns
chembl_smiles_df = df[['Molecule ChEMBL ID', 'Smiles', 'EC50']]

# Save back as TSV (overwrite same file)
chembl_smiles_df.to_csv("/content/chembl_id_smiles.tsv", sep="\t", index=False)

print("✅ Saved cleaned file → chembl_id_smiles.tsv")
# Out:
# ✅ Saved cleaned file → chembl_id_smiles.tsv

# %%
df=pd.read_csv('/content/chembl_id_smiles.tsv', sep='\t')

# %%
df.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0       CHEMBL360368  CCO[C@@H](Cc1ccc(OCCCOc2ccc(Oc3ccccc3)cc2)cc1)...
# 1       CHEMBL178321  COc1ccc2c(c1)c(Cc1ccc(C(=O)O)cc1)c(C)n2C(=O)c1...
# 2       CHEMBL104246  Cc1oc(-c2ccccc2)nc1CCOc1ccc(C[C@@H](C(=O)O)N2C...
# 3        CHEMBL66206     Cc1oc(-c2ccccc2)nc1CCOc1ccc(OC(C)(C)C(=O)O)cc1
# 4       CHEMBL194698                   CCCCCOc1ccccc1C(O)CC#CCCCC(=O)OC
#
#      EC50
# 0   282.0
# 1     NaN
# 2    24.0
# 3  2059.0
# 4   642.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5305 entries, 0 to 5304
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  5305 non-null   object
#  1   Smiles              5305 non-null   object
#  2   EC50                4933 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 124.5+ KB

# %%
# Install RDKit for calculating tanimoto similarity
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 15.8 MB/s eta 0:00:00
# ...

# %%
# Load the SMILES data for rosi and pio retrived from drug bank
smiles_df = pd.read_csv('/content/rosi and pio smiles.tsv', sep='\t')
display(smiles_df)
# Out:
#   Drugbank id   Generic name                                         Smiles
# 0     DB00412  Rosiglitazone  CN(CCOC1=CC=C(CC2SC(=O)NC2=O)C=C1)C1=CC=CC=N1
# 1     DB01132   Pioglitazone  CCC1=CN=C(CCOC2=CC=C(CC3SC(=O)NC3=O)C=C2)C=C1

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

# Convert SMILES to RDKit molecular objects and generate fingerprints
mols = [Chem.MolFromSmiles(smile) for smile in smiles_df['Smiles']]
fingerprints = [AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048) for mol in mols if mol is not None]

# Check if we have fingerprints for both molecules
if len(fingerprints) == 2:
    print("Successfully generated fingerprints for both molecules.")
else:
    print("Could not generate fingerprints for all molecules. Please check the SMILES strings.")
# Out:
# Successfully generated fingerprints for both molecules.
# [06:20:01] DEPRECATION WARNING: please use MorganGenerator
# [06:20:01] DEPRECATION WARNING: please use MorganGenerator

# %%
from rdkit import DataStructs

# Calculate Tanimoto similarity between the two rosi and pio fingerprints
if len(fingerprints) == 2:
    tanimoto_similarity = DataStructs.TanimotoSimilarity(fingerprints[0], fingerprints[1])
    print(f"Tanimoto similarity between Rosiglitazone and Pioglitazone: {tanimoto_similarity}")
else:
    print("Cannot calculate Tanimoto similarity as fingerprints were not generated for both molecules.")
# Out:
# Tanimoto similarity between Rosiglitazone and Pioglitazone: 0.5245901639344263

# %%
# calculating tanimoto similarity for 5305 compounds
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator, DataStructs
# Step 1:
# Load dataset - has chembl id, smiles, EC50
compounds_df = pd.read_csv("/content/chembl_id_smiles.tsv", sep="\t")

# Load datset - pio and rosi as reference compound for calculating tanimoto
ref_df = pd.read_csv("/content/rosi and pio smiles.tsv", sep="\t")


# Step 2: Setup Morgan generator
morgan_gen = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

def smiles_to_fp(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return morgan_gen.GetFingerprint(mol)
    else:
        return None

# Step 3: Get reference compounds
rosi_smiles = ref_df.loc[ref_df["Generic name"].str.contains("Rosi", case=False), "Smiles"].values[0]
pio_smiles  = ref_df.loc[ref_df["Generic name"].str.contains("Pio", case=False), "Smiles"].values[0]

rosi_fp = smiles_to_fp(rosi_smiles)
pio_fp  = smiles_to_fp(pio_smiles)

# Step 4: Compute tanimoto similarities
rosi_sims = []
pio_sims = []

for smi in compounds_df["Smiles"]:
    fp = smiles_to_fp(smi)
    if fp:
        rosi_sims.append(round(DataStructs.TanimotoSimilarity(rosi_fp, fp),4))
        pio_sims.append(round(DataStructs.TanimotoSimilarity(pio_fp, fp),4))
    else:
        rosi_sims.append(None)
        pio_sims.append(None)

compounds_df["Tanimoto_with_Rosi"] = rosi_sims
compounds_df["Tanimoto_with_Pio"]  = pio_sims


# Step 5: doing Average similarity to filter compounds

compounds_df["Average_Similarity"] = (
    compounds_df["Tanimoto_with_Rosi"] + compounds_df["Tanimoto_with_Pio"]
) / 2
compounds_df["Average_Similarity"] = compounds_df["Average_Similarity"].round(4)


# Step 6: Save results

output_file = "/content/pairwise_tanimoto_results.tsv"
compounds_df.to_csv(output_file, sep="\t", index=False)

print("✅ Done! Results saved to:", output_file)
compounds_df.head()
# Out:
# ✅ Done! Results saved to: /content/pairwise_tanimoto_results.tsv
#   Molecule ChEMBL ID                                             Smiles  \
# 0       CHEMBL360368  CCO[C@@H](Cc1ccc(OCCCOc2ccc(Oc3ccccc3)cc2)cc1)...
# 1       CHEMBL178321  COc1ccc2c(c1)c(Cc1ccc(C(=O)O)cc1)c(C)n2C(=O)c1...
# 2       CHEMBL104246  Cc1oc(-c2ccccc2)nc1CCOc1ccc(C[C@@H](C(=O)O)N2C...
# 3        CHEMBL66206     Cc1oc(-c2ccccc2)nc1CCOc1ccc(OC(C)(C)C(=O)O)cc1
# 4       CHEMBL194698                   CCCCCOc1ccccc1C(O)CC#CCCCC(=O)OC
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity
# 0   282.0              0.2609             0.2537              0.2573
# 1     NaN              0.1412             0.1463              0.1438
# 2    24.0              0.2381             0.2317              0.2349
# 3  2059.0              0.2400             0.2329              0.2364
# 4   642.0              0.1463             0.1375              0.1419

# %%
# fixing Threshold value of rosi and pio tanimoto sim score
threshold = 0.5245

# Count how many compounds pass
count_above = (compounds_df['Average_Similarity']>= threshold).sum()


# Total compounds
total_compounds = len(compounds_df)

# Print results
print(f"Compounds with Average_Similarity >= {threshold}: {count_above}")


# save filtered compounds
filtered_df = compounds_df[compounds_df["Average_Similarity"] >= threshold]
filtered_df.to_csv("/content/threshold_compounds.tsv", sep="\t", index=False)

print("Filtered compounds saved to: /content/threshold_compounds.tsv")
# Out:
# Compounds with Average_Similarity >= 0.5245: 219
# Filtered compounds saved to: /content/threshold_compounds.tsv

# %%
df=pd.read_csv('/content/threshold_compounds.tsv' , sep='\t')

# %%
df.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 2        CHEMBL17805       CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2o1
# 3          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL843  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity
# 0   89.13              1.0000             0.5246              0.7623
# 1   50.00              1.0000             0.5246              0.7623
# 2   11.22              0.6557             0.4848              0.5702
# 3  120.00              1.0000             0.5246              0.7623
# 4  730.00              0.8727             0.4706              0.6717

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  219 non-null    object
#  1   Smiles              219 non-null    object
#  2   EC50                218 non-null    float64
#  3   Tanimoto_with_Rosi  219 non-null    float64
#  4   Tanimoto_with_Pio   219 non-null    float64
#  5   Average_Similarity  219 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 10.4+ KB

# %%
# labeling 1 to threshold compounds(219)

# Load the TSV file
df = pd.read_csv("/content/threshold_compounds.tsv", sep="\t")

# Add Label column with value 1 for all rows
df["Label"] = 1

# Save back to file (overwrite or new file)
df.to_csv("/content/threshold_compounds.tsv", sep="\t", index=False)

# Show first few rows to confirm
df.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 2        CHEMBL17805       CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2o1
# 3          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL843  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity  Label
# 0   89.13              1.0000             0.5246              0.7623      1
# 1   50.00              1.0000             0.5246              0.7623      1
# 2   11.22              0.6557             0.4848              0.5702      1
# 3  120.00              1.0000             0.5246              0.7623      1
# 4  730.00              0.8727             0.4706              0.6717      1

# %%
# filtering compounds which is close to threshold value
import pandas as pd
# Load the file
df = pd.read_csv("/content/pairwise_tanimoto_results.tsv", sep="\t")

# Step 1: Filter compounds in the range 0.50–0.53
close_to_threshold = df[(df["Average_Similarity"] >= 0.50) & (df["Average_Similarity"] <= 0.53)]

# Step 2: Remove compounds exactly equal to 0.5245 (your threshold)
final = close_to_threshold[(close_to_threshold["Average_Similarity"] != 0.5245) & (close_to_threshold["Average_Similarity"] !=0.5298)]

# Save results
final.to_csv("/content/compounds_close_to_0.5245.tsv", sep="\t", index=False)

# %%
df=pd.read_csv('/content/compounds_close_to_0.5245.tsv', sep='\t')

# %%
df.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0       CHEMBL125895  C/C(=N\OCCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccc(-c2c...
# 1      CHEMBL4126802  COc1ccc(C(OCCOc2ccc(CC3SC(=O)NC3=O)cc2)c2ccccc...
# 2      CHEMBL4127761         O=C1NC(=O)C(Cc2ccc(OCCn3cnc4ccccc43)cc2)S1
# 3       CHEMBL125363       C/C(=N\OCCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccncc1
# 4       CHEMBL341105       C/C(=N\OCCOc1ccc(CC2SC(=O)NC2=O)cc1)c1cccnc1
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity
# 0   640.0              0.5441             0.4571              0.5006
# 1     NaN              0.5156             0.4921              0.5038
# 2  2320.0              0.5238             0.5000              0.5119
# 3  7900.0              0.5156             0.5161              0.5158
# 4  2800.0              0.5075             0.5077              0.5076

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  16 non-null     object
#  1   Smiles              16 non-null     object
#  2   EC50                14 non-null     float64
#  3   Tanimoto_with_Rosi  16 non-null     float64
#  4   Tanimoto_with_Pio   16 non-null     float64
#  5   Average_Similarity  16 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 900.0+ bytes

# %%
# labeling the compound close to threshold value

# Load the dataset
file_path = '/content/compounds_close_to_0.5245.tsv'
df_close = pd.read_csv(file_path, sep='\t')

# Apply labeling based on EC50
# Label 1 if EC50 <= 1000 or if EC50 is missing
# Label 0 if EC50 > 1000
df_close['Label'] = df_close['EC50'].apply(lambda x: 1 if pd.isna(x) or x <= 1000 else 0)

# Save back to the same file
df_close.to_csv(file_path, sep='\t', index=False)

print(f"✅ Compounds in {file_path} labeled based on EC50 and saved.")

# Display the first few rows to show the updated 'Label' column
display(df_close.head())

# Display info to show the updated non-null count for the 'Label' column
df_close.info()
# Out:
# ✅ Compounds in /content/compounds_close_to_0.5245.tsv labeled based on EC50 and saved.
#   Molecule ChEMBL ID                                             Smiles  \
# 0       CHEMBL125895  C/C(=N\OCCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccc(-c2c...
# 1      CHEMBL4126802  COc1ccc(C(OCCOc2ccc(CC3SC(=O)NC3=O)cc2)c2ccccc...
# 2      CHEMBL4127761         O=C1NC(=O)C(Cc2ccc(OCCn3cnc4ccccc43)cc2)S1
# 3       CHEMBL125363       C/C(=N\OCCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccncc1
# 4       CHEMBL341105       C/C(=N\OCCOc1ccc(CC2SC(=O)NC2=O)cc1)c1cccnc1
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity  Label
# 0   640.0              0.5441             0.4571              0.5006      1
# 1     NaN              0.5156             0.4921              0.5038      1
# 2  2320.0              0.5238             0.5000              0.5119      0
# 3  7900.0              0.5156             0.5161              0.5158      0
# ...

# %%
# Merging the filtered compounds(threshold value) and close to threshold

# Load the two files
filtered_df = pd.read_csv("/content/filtered_compounds.tsv", sep="\t")
close_to_threshold_df = pd.read_csv("/content/compounds_close_to_0.5245.tsv", sep="\t")

# Merge the two dataframes
merged_df = pd.concat([filtered_df, close_to_threshold_df], ignore_index=True)

# Sort the merged dataframe by the 'Label' column (1s first, then 0s)
merged_df_ordered = merged_df.sort_values(by='Label', ascending=False)

# Display the first few rows of the merged and ordered dataframe
display(merged_df_ordered.head())

# Print the info of the merged and ordered dataframe
print("\nMerged and Ordered DataFrame Info:")
merged_df_ordered.info()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 2        CHEMBL17805       CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2o1
# 3          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL843  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity  Label
# 0   89.13              1.0000             0.5246              0.7623      1
# 1   50.00              1.0000             0.5246              0.7623      1
# 2   11.22              0.6557             0.4848              0.5702      1
# 3  120.00              1.0000             0.5246              0.7623      1
# 4  730.00              0.8727             0.4706              0.6717      1
# Merged and Ordered DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# save the merged compounds

# Save the merged and ordered dataframe
output_file = "/content/merged_compounds.tsv"
merged_df_ordered.to_csv(output_file, sep="\t", index=False)

# %%
df=pd.read_csv('/content/merged_compounds.tsv', sep='\t')

# %%
df.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 1          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 2        CHEMBL17805       CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2o1
# 3          CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL843  CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1.O=C(O)...
#
#      EC50  Tanimoto_with_Rosi  Tanimoto_with_Pio  Average_Similarity  Label
# 0   89.13              1.0000             0.5246              0.7623      1
# 1   50.00              1.0000             0.5246              0.7623      1
# 2   11.22              0.6557             0.4848              0.5702      1
# 3  120.00              1.0000             0.5246              0.7623      1
# 4  730.00              0.8727             0.4706              0.6717      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  236 non-null    object
#  1   Smiles              236 non-null    object
#  2   EC50                232 non-null    float64
#  3   Tanimoto_with_Rosi  236 non-null    float64
#  4   Tanimoto_with_Pio   236 non-null    float64
#  5   Average_Similarity  236 non-null    float64
#  6   Label               236 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 13.0+ KB

# %%
# filtering the remaining compounds

# Load the pairwise tanimoto results dataframe
pairwise_df = pd.read_csv("/content/pairwise_tanimoto_results.tsv", sep="\t")

# Filter compounds with average similarity less than 0.49
compounds_less_than_049 = pairwise_df[pairwise_df["Average_Similarity"] <= 0.49].copy()
#label them as 0
compounds_less_than_049["Label"] = 0

# Save the filtered dataframe to a new file
output_file_less_than_049 = "/content/remaining compounds.tsv"
compounds_less_than_049.to_csv(output_file_less_than_049, sep="\t", index=False)

print(f"✅ Compounds with Average_Similarity less than 0.49 saved to: {output_file_less_than_049}")
# Out:
# ✅ Compounds with Average_Similarity less than 0.49 saved to: /content/remaining compounds.tsv

# %%
df=pd.read_csv('/content/remaining compounds.tsv', sep='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5070 entries, 0 to 5069
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Molecule ChEMBL ID  5070 non-null   object
#  1   Smiles              5070 non-null   object
#  2   EC50                4701 non-null   float64
#  3   Tanimoto_with_Rosi  5070 non-null   float64
#  4   Tanimoto_with_Pio   5070 non-null   float64
#  5   Average_Similarity  5070 non-null   float64
#  6   Label               5070 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 277.4+ KB
